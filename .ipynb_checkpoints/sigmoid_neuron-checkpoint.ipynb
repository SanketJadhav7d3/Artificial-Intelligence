# %% [markdown]
# # Sigmoid Neuron
# Sigmoid neurons are similar to perceptron neuron but then the only difference between them is that Sigmoid neuron are smoother than percentron neurons.
#
# ![Screenshot 2023-02-09 at 4.25.13 PM.png](attachment:2a6b200a-bc00-44f1-94b4-640109c2340f.png)
#
# # Properties of Sigmoid Neurons are
#
# * Continous
# * Smooth
# * Differentiable

# %%
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
from ipywidgets import HBox, VBox

# %%
# code implementation of above formula
def sigmoid(x: list, w: list, b: float):
    return 1 / (1 + np.exp(-(np.dot(x, w) + b)))

# %%
# for 1 input
xs = np.arange(-10, 10, 0.1)
w = 1
b = 0

@widgets.interact(weight=(1,50), bias=(-30, 30))
def plot_sigmoid(weight=1., bias=0):
    plt.plot(xs, sigmoid(xs, weight, bias))
# Out:
# interactive(children=(IntSlider(value=1, description='weight', max=50, min=1), IntSlider(value=0, description=…

# %%
ax = plt.figure().add_subplot(projection='3d')

x1 = np.arange(-10, 10, 0.1) 
x2 = np.arange(-5, 5, 0.19999999) 

# tray changing value of 21 and b
w1 = 10
b=-40

def sigmoid2d(x1, w1, b=1):
    return 1 / (1 + np.exp(-(x1 * w1 + b))) 

zs = sigmoid2d(x1, w1, b)
 
for i in x2:
    dummy = [i for _ in range(len(x1))]
    plt.plot(x1, dummy, zs, 'slategray')

# %% [markdown]
# # Learning Algorithm
